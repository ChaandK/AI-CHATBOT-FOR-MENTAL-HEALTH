# %%
##IMPORTING LIBRARIES

import pickle    #for serializing python objects (Eg- Saving models)
import random    #used to get random numbers
import json      #for working with JSON files

import numpy as np    #for numerical operations
import nltk           #for tokenizing and lemmatizing text
from nltk.stem import WordNetLemmatizer

#tensorflow.keras is used here to build DL models, and specifically using Keras, a high level API for  building neural networks within TF
from tensorflow.keras.models import Sequential          #Sequential is a special case of model where model is purely a stck of single-input, single-output layers
from tensorflow.keras.layers import Dense, Activation, Dropout      #Dense (Basic building block where every input connects to every output)
#Activation func. (Decides if a neuron should be activated or not, making the network smart)
#Dropout (Randomly ignores some neurons during training to make the network better at generalizing)

from tensorflow.keras.optimizers import SGD   #Stochastic gradient descent

# %%
nltk.download('punkt_tab') #for sentence tokenization
nltk.download('wordnet') #A lexical database fpr semantic understanding
nltk.download('omw-1.4')    #Open multilingual WordNet
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\chaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\chaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\chaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
# intents = json.loads(intents_file)  #loads JSON file

# intents = json.loads(open('intents.json').read()) 

import json  

# Safely open and read the JSON file with the correct encoding  
try:  
    # Specify the encoding as UTF-8  
    with open('intents.json', 'r', encoding='utf-8') as file:  
        intents = json.load(file)  # Load the JSON data from the file  
except FileNotFoundError:  
    print("Error: The file 'intents.json' was not found.")  
except json.JSONDecodeError:  
    print("Error: The file 'intents.json' contains invalid JSON.")  
except UnicodeDecodeError as e:  
    print(f"Encoding error: {e}. It seems the file might not be encoded in 'utf-8'.")  
except Exception as e:  
    print(f"An unexpected error occurred: {e}")  

# Now you can use 'intents' as a regular Python data structure

# %%
lemmatizer = WordNetLemmatizer()  #converts into base or root form [Eg- 'Running' to 'Run]

# intents = json.load(open('intents.json'))  #loads JSON File

words = []   #to store all words found in the training patterns
classes = []  #to store unique intent tags (categories) [Eg- 'greeting' or 'neutral-response']
documents = []  #a list of tuples where each tuple contains a tokenized sentence (word list) and its associated intent tag
Ignore_Symbols = [',', '.', '?', '!']   #Specifies characters to ignore

# %%
for intent in intents['intents']:   #to go through all the intents in the json file
    tag = intent['tag']
    for pattern in intent['patterns']:   #to go through all the patterns in the intents
        word_list = nltk.word_tokenize(pattern)            #splits the sentences into individual words

        #tokenize and lemmatize each word in the pattern
        words_list = [lemmatizer.lemmatize(word.lower()) for word in nltk.word_tokenize(pattern) if word not in Ignore_Symbols]

        #Add words and documents
        words.extend(word_list)          #Add the tokenized words to the words list
        documents.append((word_list, tag))      #Appends the tokenized pattern and its tag as a tuple to documents

        #Add the tag to the classes if its not already present
        if tag not in classes:
            classes.append(tag)

# %%
#Removes duplicates by converting to a set, then back to a list, to ensure that the entries are unique and unordered
words = sorted(set(words))       #sorted() - converts the sets back to lists and sorts them
classes = sorted(set(classes))

# %%
#Saving data with pickle; saves the words and classes lists to files using pickle module
#It enables you to load them later without reprocessing
pickle.dump(words, open('model_words.pkl', 'wb'))
pickle.dump(classes, open('model_classes.pkl', 'wb'))

# %%
#Preparing training data;
training = []    #will store input-output pairs for training the model
output_empty = [0] * len(classes)       #creates a list of zeroes with equal length to the number of unique classes; this serves as a template for the output

# %%
##Focuses on converting the textual input and output into numeric format for ML algo

for document in documents:         #Iterates through each document in the documents list (Document is a tuple containing a tokenized sentence and its associated tag)
    bag = []        #Initialized to store an empty list for each bag of words
    word_patterns = document[0]         #Get the tokenized words from the documents
    word_patterns = [lemmatizer.lemmatize(word) for word in word_patterns if word not in Ignore_Symbols]        #Each word is being lemmatize while ignoring symbols defined in Ignore_Symbols

    for word in words:          #For each word in the words list (contains all unique words from training dataset), it checks if that word is present in word_patterns
        bag.append(1) if word in word_patterns else bag.append(0)       #It appends '1' if the word is present and '0' if not; creating binary representation of whether each word exists in the current document

    output_row = list(output_empty)         #create an output row initialized to zeroes; which is of same length as the number of unique classes (intents)
    output_row[classes.index(document[1])] = 1      #The index in output_row that corresponds to the current document's intent tag (document[1]) is set to '1'; Indicates the this particular output(class) is active
    training.append([bag, output_row])      #Append the bag and output row pair to the training list; Each entry in 'training' will be a pair of input features(bag of words) and the corresponding output (the intent representation)

# %%
random.shuffle(training)        #training list is shuffled to mix the order of samples; helps in preventing model from learning the sequence of training samples
training = np.array(training, dtype=object)   #Convert the list to numpy array for easier manipulation; use dtype=object for variable length arrays

train_x = list(training[:, 0])      #Extracts the input features (bag of words) from training array and converts it to the list
train_y = list(training[:, 1])      #Extracts the output labels (one-hot encoded intents) from training array and converts it into list

## ONE-HOT ENCODING - method for converting categorical variables into binary format (0s and 1s, where '1' indicates the presence of that category and '0' indicates its absence)

# %%
model = Sequential()    #initializes a sequential model, which is a type of neural network where the layers are stacked sequentially

# %%
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))    #Dense(128) - adds a fully connected (dense) layer with 128 neurons(units). Each neuron will compute its output based on its inputs through weights and biases.
#input_shape=(len(train_x[0]),) - defines the input shape for the first layer. len(train_x[0]) indicates the number of features in the i/p data, ensuring the first layer knows how many inputs it will receive(the dimension of the feature vector).
#activation='relu' - specifies the activation function for the layer.
#The rectified Linear unit (ReLU) activation function is used because it helps mitigate issues like vanishing gradients and allows the network to learn complex patterns. It outputs the input directly if its positive; otherwise it outputs zero.

model.add(Dropout(0.5)) #This layer randomly sets 50% of the inputs to zero during training.
#Dropout is a regularization technique that helps prevent overfitting by ensuring that the model does not rely too heavily on any particular neuron.

# %%
model.add(Dense(64, activation='relu')) #Another dense layer with 64 neurons is added, again using ReLU activation function. This layer will learn complex representations and patterns from the input data.

model.add(Dropout(0.5))     #this adds regularization again to help reduce overfitting by randomly setting 50% of the activations to zero in the layer preceding it.

# %%
model.add(Dense(len(train_y[0]), activation='softmax'))     #this is the output layer of the network.
#The number of neurons in this layer equals the number of unique classes(intents), which corresponds to the length of train_y[0](the one-hot encoding o/p)
#activation='softmax' - used in output for multi-class classification problems. It converts the output into a probability distribution; each output value represents the relative likelihood of each class.

# %%
sgd = SGD(learning_rate=0.001, weight_decay=0.0001, nesterov=True) #SGD - this initializes Stochastic Gradient Descent optimizer, which updates the model weights based on the gradients of the loss function.
#learning_rate=0.001 - the step size at each iteration while moving towards a minimum of the loss function.
#weight_decay=1e-6 - this parameter applies L2 regularization to the weights, helping to prevent overfitting by penalizing large weights.
#Regularization is any mechanism that reduces overfitting.
#L1 regularization - a type of regularization that penalizes weights in proportion to the sum of the absolute value of the weights. L1 regularization helps drive the weights of irrelevant or barely relevant features to exactly 0. A feature with weight of 0 is effectively removed from the model.
#L2 regularization - a type of regularization that penalizes weights in proportions to the sum of the squares of the weights. L regularization helps drive outlier weights (those with high positive or low negative values) closer to 0 but not quite 0. Features with values very close to 0 remain in the model but don't influence the model's predictions very much.
#momentum=0.9 - this parameter helps accelerate SGD in the relevant direction and dampens oscillations; it is a technique used in gradient descent, which is a method for optimizing functions. Instead of just looking at the slope (or gradient) of the function at the current point to decide how to move, momentum also considers the slopes from the previous steps.
#nestrov=True - this enables Nestrov momentum, which provides a more responsive and faster convergence compares to standard momentum

# %%
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"]) #compiles the model
#loss="categorical_crossentropy" - specifies the loss function to be used for training. Categorical cross-entropy is suitable for multi class classification problems, where the target outcomes are one-hot encoded.
#optimizer=sgd - sets the optimizer defined earlier to be used during training.
#metrics=["accuracy"] - performance measure during training and validation. This will track accuracy through out the training process.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(  
    monitor='val_loss',      # Metric to monitor  
    patience=5,              # Number of epochs to wait before stopping  
    restore_best_weights=True # Restore the model weights from the epoch with the best value of the monitored quantity  
)

# %%
model.fit(np.array(train_x), np.array(train_y), epochs=500, batch_size=32,  verbose=1) #fitting the model
#model.fit() - this methods starts the training proces
#np.array(train_x), np.array(train_y) - converts the training input features and corresponding labels into a numpy arrays(if not already in that format).
#epochs=50 - the number of times the entire training dataset will pass through the model.
#batch_size=5 - number of samples per gradient update. smaller batch provides regualar updates but can lead to more noisy gradients.
#verbose=1 - this controls the verbosity of the output during training. Setting it to 1 shows progress updates.
# Out:
# Epoch 1/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0098 - loss: 4.4971
# Epoch 2/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0462 - loss: 4.4740
# Epoch 3/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1205 - loss: 4.4529
# Epoch 4/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1745 - loss: 4.4304
# Epoch 5/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1975 - loss: 4.4083
# Epoch 6/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2028 - loss: 4.3840
# Epoch 7/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2241 - loss: 4.3532
# Epoch 8/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2038 - loss: 4.3334
# Epoch 9/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2028 - loss: 4.3060
# Epoch 10/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2105 - loss: 4.2655
# Epoch 11/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1925 - loss: 4.2415
# Epoch 12/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.2027 - loss: 4.1953
# Epoch 13/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.1884 - loss: 4.1675
# Epoch 14/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.1944 - loss: 4.1146
# Epoch 15/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1944 - loss: 4.0604
# Epoch 16/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1940 - loss: 4.0039
# Epoch 17/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1895 - loss: 3.9485
# Epoch 18/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1949 - loss: 3.8409
# Epoch 19/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1911 - loss: 3.8010
# Epoch 20/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1966 - loss: 3.7321
# Epoch 21/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1907 - loss: 3.6961
# Epoch 22/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1933 - loss: 3.6553
# Epoch 23/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2107 - loss: 3.5733
# Epoch 24/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1981 - loss: 3.5642
# Epoch 25/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2054 - loss: 3.5288
# Epoch 26/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2056 - loss: 3.5145
# Epoch 27/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2194 - loss: 3.4385
# Epoch 28/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2282 - loss: 3.3970
# Epoch 29/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2246 - loss: 3.3898
# Epoch 30/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2367 - loss: 3.3581
# Epoch 31/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2561 - loss: 3.2773
# Epoch 32/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2648 - loss: 3.2730
# Epoch 33/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2694 - loss: 3.2672
# Epoch 34/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2775 - loss: 3.2075
# Epoch 35/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.3011 - loss: 3.1456
# Epoch 36/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2852 - loss: 3.2010
# Epoch 37/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.2958 - loss: 3.1377
# Epoch 38/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3176 - loss: 3.1029
# Epoch 39/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3170 - loss: 3.0769
# Epoch 40/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3222 - loss: 3.0799
# Epoch 41/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3298 - loss: 3.0609
# Epoch 42/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3278 - loss: 3.0133
# Epoch 43/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3599 - loss: 2.9610
# Epoch 44/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3402 - loss: 2.9715
# Epoch 45/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3565 - loss: 2.9085
# Epoch 46/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3521 - loss: 2.9255
# Epoch 47/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3693 - loss: 2.8343
# Epoch 48/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3718 - loss: 2.8412
# Epoch 49/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3646 - loss: 2.8505
# Epoch 50/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3674 - loss: 2.8065
# Epoch 51/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3814 - loss: 2.7772
# Epoch 52/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3837 - loss: 2.7726
# Epoch 53/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3816 - loss: 2.7651
# Epoch 54/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3909 - loss: 2.7346
# Epoch 55/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3903 - loss: 2.7106
# Epoch 56/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4015 - loss: 2.6746
# Epoch 57/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3944 - loss: 2.6970
# Epoch 58/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3973 - loss: 2.6503
# Epoch 59/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3975 - loss: 2.6650
# Epoch 60/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4060 - loss: 2.6159
# Epoch 61/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3977 - loss: 2.6609
# Epoch 62/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4109 - loss: 2.6100
# Epoch 63/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4080 - loss: 2.6050
# Epoch 64/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4137 - loss: 2.5906
# Epoch 65/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4073 - loss: 2.6149
# Epoch 66/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4259 - loss: 2.5421
# Epoch 67/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4306 - loss: 2.5341
# Epoch 68/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4326 - loss: 2.5153
# Epoch 69/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4310 - loss: 2.5055
# Epoch 70/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4168 - loss: 2.5454
# Epoch 71/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4264 - loss: 2.5210
# Epoch 72/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4317 - loss: 2.4941
# Epoch 73/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4310 - loss: 2.5060
# Epoch 74/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4406 - loss: 2.4553
# Epoch 75/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4454 - loss: 2.4389
# Epoch 76/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4483 - loss: 2.4405
# Epoch 77/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4491 - loss: 2.4239
# Epoch 78/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4429 - loss: 2.4509
# Epoch 79/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4601 - loss: 2.3770
# Epoch 80/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4470 - loss: 2.4249
# Epoch 81/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4517 - loss: 2.4143
# Epoch 82/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4615 - loss: 2.3827
# Epoch 83/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4627 - loss: 2.3627
# Epoch 84/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4656 - loss: 2.3365
# Epoch 85/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4641 - loss: 2.3572
# Epoch 86/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4697 - loss: 2.3285
# Epoch 87/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4636 - loss: 2.3434
# Epoch 88/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4686 - loss: 2.3331
# Epoch 89/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4631 - loss: 2.3460
# Epoch 90/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4601 - loss: 2.3557
# Epoch 91/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4647 - loss: 2.3429
# Epoch 92/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4779 - loss: 2.3049
# Epoch 93/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4806 - loss: 2.2789
# Epoch 94/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4769 - loss: 2.2767
# Epoch 95/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4801 - loss: 2.2679
# Epoch 96/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.4843 - loss: 2.2368
# Epoch 97/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4880 - loss: 2.2040
# Epoch 98/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4762 - loss: 2.2474
# Epoch 99/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4804 - loss: 2.2439
# Epoch 100/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4858 - loss: 2.2395
# Epoch 101/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.4883 - loss: 2.1871
# Epoch 102/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4813 - loss: 2.2505
# Epoch 103/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4857 - loss: 2.1994
# Epoch 104/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4806 - loss: 2.2358
# Epoch 105/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4748 - loss: 2.2519
# Epoch 106/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4948 - loss: 2.1968
# Epoch 107/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4810 - loss: 2.2059
# Epoch 108/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4836 - loss: 2.2105
# Epoch 109/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4861 - loss: 2.1916
# Epoch 110/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4950 - loss: 2.1561
# Epoch 111/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4928 - loss: 2.1555
# Epoch 112/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4881 - loss: 2.1631
# Epoch 113/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4970 - loss: 2.1399
# Epoch 114/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4905 - loss: 2.1619
# Epoch 115/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5052 - loss: 2.1123
# Epoch 116/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5063 - loss: 2.1068
# Epoch 117/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4934 - loss: 2.1472
# Epoch 118/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5008 - loss: 2.1322
# Epoch 119/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5001 - loss: 2.0985
# Epoch 120/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5041 - loss: 2.0919
# Epoch 121/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5012 - loss: 2.1212
# Epoch 122/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4996 - loss: 2.0893
# Epoch 123/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5021 - loss: 2.0926
# Epoch 124/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4900 - loss: 2.1415
# Epoch 125/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5041 - loss: 2.1199
# Epoch 126/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5066 - loss: 2.1071
# Epoch 127/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5192 - loss: 2.0229
# Epoch 128/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5044 - loss: 2.1040
# Epoch 129/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5079 - loss: 2.0871
# Epoch 130/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5178 - loss: 2.0497
# Epoch 131/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5181 - loss: 2.0490
# Epoch 132/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5204 - loss: 2.0483
# Epoch 133/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5089 - loss: 2.0780
# Epoch 134/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5063 - loss: 2.0850
# Epoch 135/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5048 - loss: 2.0929
# Epoch 136/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5152 - loss: 2.0345
# Epoch 137/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5174 - loss: 2.0112
# Epoch 138/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5154 - loss: 2.0307
# Epoch 139/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5168 - loss: 2.0432
# Epoch 140/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5132 - loss: 2.0712
# Epoch 141/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5215 - loss: 2.0126
# Epoch 142/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5256 - loss: 2.0256
# Epoch 143/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5141 - loss: 2.0728
# Epoch 144/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5272 - loss: 1.9898
# Epoch 145/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5165 - loss: 2.0412
# Epoch 146/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5356 - loss: 1.9471
# Epoch 147/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5279 - loss: 2.0071
# Epoch 148/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5259 - loss: 1.9965
# Epoch 149/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5458 - loss: 1.9105
# Epoch 150/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5374 - loss: 1.9524
# Epoch 151/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5233 - loss: 2.0100
# Epoch 152/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5253 - loss: 1.9850
# Epoch 153/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5292 - loss: 1.9700
# Epoch 154/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5316 - loss: 1.9814
# Epoch 155/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5377 - loss: 1.9664
# Epoch 156/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5373 - loss: 1.9416
# Epoch 157/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5416 - loss: 1.9358
# Epoch 158/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5375 - loss: 1.9621
# Epoch 159/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5353 - loss: 1.9378
# Epoch 160/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5410 - loss: 1.9482
# Epoch 161/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5396 - loss: 1.9597
# Epoch 162/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5363 - loss: 1.9487
# Epoch 163/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5419 - loss: 1.9133
# Epoch 164/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5477 - loss: 1.8935
# Epoch 165/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5374 - loss: 1.9521
# Epoch 166/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5451 - loss: 1.9367
# Epoch 167/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5463 - loss: 1.9272
# Epoch 168/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5465 - loss: 1.9055
# Epoch 169/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5589 - loss: 1.8928
# Epoch 170/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5458 - loss: 1.9029
# Epoch 171/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5529 - loss: 1.8554
# Epoch 172/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5437 - loss: 1.9024
# Epoch 173/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5517 - loss: 1.8900
# Epoch 174/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5413 - loss: 1.9302
# Epoch 175/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5359 - loss: 1.9480
# Epoch 176/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5553 - loss: 1.8905
# Epoch 177/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5593 - loss: 1.8832
# Epoch 178/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5644 - loss: 1.8620
# Epoch 179/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5540 - loss: 1.8766
# Epoch 180/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5478 - loss: 1.8924
# Epoch 181/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5643 - loss: 1.8276
# Epoch 182/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5477 - loss: 1.8828
# Epoch 183/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5624 - loss: 1.8473
# Epoch 184/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5506 - loss: 1.8635
# Epoch 185/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5606 - loss: 1.8718
# Epoch 186/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5697 - loss: 1.8140
# Epoch 187/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5587 - loss: 1.8491
# Epoch 188/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5603 - loss: 1.8421
# Epoch 189/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5718 - loss: 1.8027
# Epoch 190/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5689 - loss: 1.8272
# Epoch 191/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5742 - loss: 1.8104
# Epoch 192/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5736 - loss: 1.7983
# Epoch 193/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5657 - loss: 1.8373
# Epoch 194/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5726 - loss: 1.8000
# Epoch 195/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5599 - loss: 1.8560
# Epoch 196/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5703 - loss: 1.8001
# Epoch 197/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5622 - loss: 1.8202
# Epoch 198/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5652 - loss: 1.8155
# Epoch 199/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5676 - loss: 1.8110
# Epoch 200/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5608 - loss: 1.8301
# Epoch 201/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5657 - loss: 1.8221
# Epoch 202/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5721 - loss: 1.8181
# Epoch 203/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5828 - loss: 1.7615
# Epoch 204/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5888 - loss: 1.7474
# Epoch 205/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5682 - loss: 1.7956
# Epoch 206/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5743 - loss: 1.7853
# Epoch 207/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5856 - loss: 1.7642
# Epoch 208/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5714 - loss: 1.7972
# Epoch 209/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5757 - loss: 1.7687
# Epoch 210/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5781 - loss: 1.7682
# Epoch 211/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5723 - loss: 1.7991
# Epoch 212/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5832 - loss: 1.7594
# Epoch 213/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5916 - loss: 1.7274
# Epoch 214/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5888 - loss: 1.7456
# Epoch 215/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5864 - loss: 1.7756
# Epoch 216/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5819 - loss: 1.7594
# Epoch 217/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5662 - loss: 1.7787
# Epoch 218/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5854 - loss: 1.7341
# Epoch 219/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5861 - loss: 1.7445
# Epoch 220/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5808 - loss: 1.7634
# Epoch 221/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5911 - loss: 1.7268
# Epoch 222/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5757 - loss: 1.7912
# Epoch 223/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5951 - loss: 1.7243
# Epoch 224/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.5920 - loss: 1.7192
# Epoch 225/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.5849 - loss: 1.7544
# Epoch 226/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5882 - loss: 1.7294
# Epoch 227/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5904 - loss: 1.7187
# Epoch 228/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5771 - loss: 1.8005
# Epoch 229/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5792 - loss: 1.7668
# Epoch 230/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5847 - loss: 1.7182
# Epoch 231/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5831 - loss: 1.7504
# Epoch 232/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5902 - loss: 1.7262
# Epoch 233/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5927 - loss: 1.6908
# Epoch 234/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5738 - loss: 1.7242
# Epoch 235/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6028 - loss: 1.6478
# Epoch 236/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5865 - loss: 1.7193
# Epoch 237/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5891 - loss: 1.7074
# Epoch 238/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5980 - loss: 1.6737
# Epoch 239/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5950 - loss: 1.6946
# Epoch 240/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5937 - loss: 1.6812
# Epoch 241/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5951 - loss: 1.6891
# Epoch 242/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5941 - loss: 1.6791
# Epoch 243/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5857 - loss: 1.7215
# Epoch 244/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5931 - loss: 1.6760
# Epoch 245/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5999 - loss: 1.6597
# Epoch 246/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5849 - loss: 1.6914
# Epoch 247/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6095 - loss: 1.6460
# Epoch 248/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6036 - loss: 1.6445
# Epoch 249/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5895 - loss: 1.6952
# Epoch 250/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6014 - loss: 1.6602
# Epoch 251/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6042 - loss: 1.6721
# Epoch 252/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5933 - loss: 1.6756
# Epoch 253/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5902 - loss: 1.6664
# Epoch 254/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6002 - loss: 1.6560
# Epoch 255/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5957 - loss: 1.6649
# Epoch 256/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5987 - loss: 1.6748
# Epoch 257/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5962 - loss: 1.6669
# Epoch 258/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6049 - loss: 1.6466
# Epoch 259/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6037 - loss: 1.6371
# Epoch 260/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6005 - loss: 1.6380
# Epoch 261/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6072 - loss: 1.6383
# Epoch 262/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6206 - loss: 1.5866
# Epoch 263/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6056 - loss: 1.6202
# Epoch 264/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6109 - loss: 1.6125
# Epoch 265/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6091 - loss: 1.6182
# Epoch 266/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6024 - loss: 1.6330
# Epoch 267/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5901 - loss: 1.6693
# Epoch 268/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6016 - loss: 1.6500
# Epoch 269/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6146 - loss: 1.6084
# Epoch 270/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6057 - loss: 1.6366
# Epoch 271/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6113 - loss: 1.6107
# Epoch 272/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6031 - loss: 1.6312
# Epoch 273/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6097 - loss: 1.6073
# Epoch 274/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6077 - loss: 1.6424
# Epoch 275/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6220 - loss: 1.5817
# Epoch 276/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6166 - loss: 1.5944
# Epoch 277/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6124 - loss: 1.5846
# Epoch 278/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6186 - loss: 1.5887
# Epoch 279/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6106 - loss: 1.6284
# Epoch 280/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6209 - loss: 1.5958
# Epoch 281/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6024 - loss: 1.6041
# Epoch 282/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6088 - loss: 1.6225
# Epoch 283/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6231 - loss: 1.5697
# Epoch 284/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6192 - loss: 1.5826
# Epoch 285/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6046 - loss: 1.6371
# Epoch 286/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5990 - loss: 1.6551
# Epoch 287/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6173 - loss: 1.5688
# Epoch 288/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6083 - loss: 1.6123
# Epoch 289/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6097 - loss: 1.6061
# Epoch 290/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6185 - loss: 1.5710
# Epoch 291/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6294 - loss: 1.5339
# Epoch 292/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6386 - loss: 1.5264
# Epoch 293/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6197 - loss: 1.5598
# Epoch 294/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6191 - loss: 1.5589
# Epoch 295/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6140 - loss: 1.5696
# Epoch 296/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6223 - loss: 1.5891
# Epoch 297/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6291 - loss: 1.5339
# Epoch 298/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6202 - loss: 1.5657
# Epoch 299/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6273 - loss: 1.5182
# Epoch 300/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6261 - loss: 1.5417
# Epoch 301/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6271 - loss: 1.5120
# Epoch 302/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6324 - loss: 1.5192
# Epoch 303/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6222 - loss: 1.5450
# Epoch 304/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6264 - loss: 1.5473
# Epoch 305/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6206 - loss: 1.5347
# Epoch 306/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6255 - loss: 1.5460
# Epoch 307/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6133 - loss: 1.5815
# Epoch 308/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6178 - loss: 1.5460
# Epoch 309/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6250 - loss: 1.5324
# Epoch 310/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6198 - loss: 1.5543
# Epoch 311/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6411 - loss: 1.4689
# Epoch 312/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6252 - loss: 1.5396
# Epoch 313/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6205 - loss: 1.5483
# Epoch 314/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6324 - loss: 1.5118
# Epoch 315/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6313 - loss: 1.5073
# Epoch 316/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6309 - loss: 1.5058
# Epoch 317/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6273 - loss: 1.5482
# Epoch 318/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6156 - loss: 1.5375
# Epoch 319/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6365 - loss: 1.5002
# Epoch 320/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6439 - loss: 1.4550
# Epoch 321/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6333 - loss: 1.5163
# Epoch 322/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6299 - loss: 1.5153
# Epoch 323/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6224 - loss: 1.5472
# Epoch 324/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6319 - loss: 1.4998
# Epoch 325/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6325 - loss: 1.5011
# Epoch 326/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6390 - loss: 1.5197
# Epoch 327/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6187 - loss: 1.5233
# Epoch 328/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6215 - loss: 1.5100
# Epoch 329/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6255 - loss: 1.4960
# Epoch 330/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6291 - loss: 1.5233
# Epoch 331/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6312 - loss: 1.5115
# Epoch 332/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6368 - loss: 1.4765
# Epoch 333/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6419 - loss: 1.4745
# Epoch 334/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6290 - loss: 1.4903
# Epoch 335/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6293 - loss: 1.5091
# Epoch 336/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6274 - loss: 1.5217
# Epoch 337/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6313 - loss: 1.4958
# Epoch 338/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6376 - loss: 1.4836
# Epoch 339/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6392 - loss: 1.4775
# Epoch 340/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6281 - loss: 1.4939
# Epoch 341/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6305 - loss: 1.5117
# Epoch 342/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6313 - loss: 1.4679
# Epoch 343/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6472 - loss: 1.4491
# Epoch 344/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6404 - loss: 1.4726
# Epoch 345/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6378 - loss: 1.4358
# Epoch 346/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6323 - loss: 1.4845
# Epoch 347/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6351 - loss: 1.4908
# Epoch 348/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6371 - loss: 1.4491
# Epoch 349/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6325 - loss: 1.4980
# Epoch 350/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6473 - loss: 1.4217
# Epoch 351/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6355 - loss: 1.4782
# Epoch 352/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6455 - loss: 1.4675
# Epoch 353/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6374 - loss: 1.4605
# Epoch 354/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6443 - loss: 1.4622
# Epoch 355/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6372 - loss: 1.4573
# Epoch 356/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6374 - loss: 1.4599
# Epoch 357/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6446 - loss: 1.4672
# Epoch 358/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6435 - loss: 1.4540
# Epoch 359/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6417 - loss: 1.4586
# Epoch 360/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6468 - loss: 1.4257
# Epoch 361/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6523 - loss: 1.4196
# Epoch 362/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6315 - loss: 1.4977
# Epoch 363/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6485 - loss: 1.4182
# Epoch 364/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6458 - loss: 1.4175
# Epoch 365/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6476 - loss: 1.4264
# Epoch 366/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6367 - loss: 1.4466
# Epoch 367/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6471 - loss: 1.4426
# Epoch 368/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6469 - loss: 1.4340
# Epoch 369/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6497 - loss: 1.4314
# Epoch 370/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6411 - loss: 1.4566
# Epoch 371/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6489 - loss: 1.4418
# Epoch 372/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6455 - loss: 1.4344
# Epoch 373/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6449 - loss: 1.4498
# Epoch 374/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6514 - loss: 1.4009
# Epoch 375/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6432 - loss: 1.4457
# Epoch 376/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6472 - loss: 1.4095
# Epoch 377/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6554 - loss: 1.3859
# Epoch 378/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6492 - loss: 1.4163
# Epoch 379/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6488 - loss: 1.4012
# Epoch 380/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6449 - loss: 1.4441
# Epoch 381/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6374 - loss: 1.4695
# Epoch 382/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6352 - loss: 1.4551
# Epoch 383/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6551 - loss: 1.4073
# Epoch 384/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6439 - loss: 1.4426
# Epoch 385/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6439 - loss: 1.4162
# Epoch 386/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6451 - loss: 1.4404
# Epoch 387/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6407 - loss: 1.4504
# Epoch 388/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6491 - loss: 1.3998
# Epoch 389/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6364 - loss: 1.4582
# Epoch 390/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6547 - loss: 1.4052
# Epoch 391/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6591 - loss: 1.3932
# Epoch 392/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6454 - loss: 1.4276
# Epoch 393/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6548 - loss: 1.3861
# Epoch 394/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6588 - loss: 1.3898
# Epoch 395/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6503 - loss: 1.4136
# Epoch 396/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6540 - loss: 1.4132
# Epoch 397/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6410 - loss: 1.4497
# Epoch 398/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6492 - loss: 1.4085
# Epoch 399/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6445 - loss: 1.4386
# Epoch 400/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6523 - loss: 1.3743
# Epoch 401/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6558 - loss: 1.3883
# Epoch 402/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6580 - loss: 1.4023
# Epoch 403/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6517 - loss: 1.3867
# Epoch 404/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6528 - loss: 1.4390
# Epoch 405/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6586 - loss: 1.3731
# Epoch 406/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6743 - loss: 1.3118
# Epoch 407/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6481 - loss: 1.4156
# Epoch 408/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6542 - loss: 1.4043
# Epoch 409/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6514 - loss: 1.4016
# Epoch 410/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6543 - loss: 1.3982
# Epoch 411/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6484 - loss: 1.4096
# Epoch 412/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6588 - loss: 1.3645
# Epoch 413/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6599 - loss: 1.3607
# Epoch 414/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6493 - loss: 1.3679
# Epoch 415/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6668 - loss: 1.3489
# Epoch 416/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6482 - loss: 1.3778
# Epoch 417/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6575 - loss: 1.3929
# Epoch 418/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6583 - loss: 1.3927
# Epoch 419/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6540 - loss: 1.3864
# Epoch 420/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6757 - loss: 1.3016
# Epoch 421/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6494 - loss: 1.3917
# Epoch 422/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6551 - loss: 1.3624
# Epoch 423/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6656 - loss: 1.3320
# Epoch 424/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6598 - loss: 1.3632
# Epoch 425/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6595 - loss: 1.3471
# Epoch 426/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6554 - loss: 1.3753
# Epoch 427/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6613 - loss: 1.3590
# Epoch 428/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6748 - loss: 1.3388
# Epoch 429/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6713 - loss: 1.3178
# Epoch 430/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6600 - loss: 1.3568
# Epoch 431/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 1.3587
# Epoch 432/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6680 - loss: 1.3087
# Epoch 433/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6673 - loss: 1.3186
# Epoch 434/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6734 - loss: 1.3117
# Epoch 435/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6638 - loss: 1.3521
# Epoch 436/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6578 - loss: 1.3726
# Epoch 437/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6613 - loss: 1.3663
# Epoch 438/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6507 - loss: 1.3546
# Epoch 439/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6583 - loss: 1.3727
# Epoch 440/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6641 - loss: 1.3624
# Epoch 441/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6673 - loss: 1.3031
# Epoch 442/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6587 - loss: 1.3665
# Epoch 443/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6676 - loss: 1.3509
# Epoch 444/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6667 - loss: 1.3210
# Epoch 445/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6733 - loss: 1.3050
# Epoch 446/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6579 - loss: 1.3803
# Epoch 447/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6698 - loss: 1.3132
# Epoch 448/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6691 - loss: 1.3009
# Epoch 449/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6627 - loss: 1.3391
# Epoch 450/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6538 - loss: 1.3871
# Epoch 451/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6687 - loss: 1.3130
# Epoch 452/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6646 - loss: 1.3413
# Epoch 453/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6709 - loss: 1.3386
# Epoch 454/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6569 - loss: 1.3711
# Epoch 455/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6742 - loss: 1.2977
# Epoch 456/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6694 - loss: 1.3202
# Epoch 457/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6723 - loss: 1.3099
# Epoch 458/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6710 - loss: 1.3045
# Epoch 459/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6677 - loss: 1.3193
# Epoch 460/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6668 - loss: 1.3164
# Epoch 461/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6713 - loss: 1.3146
# Epoch 462/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6735 - loss: 1.3211
# Epoch 463/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6656 - loss: 1.3305
# Epoch 464/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6650 - loss: 1.3117
# Epoch 465/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6602 - loss: 1.3493
# Epoch 466/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6705 - loss: 1.3352
# Epoch 467/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6618 - loss: 1.3498
# Epoch 468/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6646 - loss: 1.3420
# Epoch 469/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6684 - loss: 1.3059
# Epoch 470/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6721 - loss: 1.3330
# Epoch 471/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6818 - loss: 1.2874
# Epoch 472/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6668 - loss: 1.3252
# Epoch 473/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6653 - loss: 1.3379
# Epoch 474/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6680 - loss: 1.3209
# Epoch 475/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6772 - loss: 1.2713
# Epoch 476/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6755 - loss: 1.2707
# Epoch 477/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6769 - loss: 1.2951
# Epoch 478/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6811 - loss: 1.2680
# Epoch 479/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6751 - loss: 1.2758
# Epoch 480/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6662 - loss: 1.3151
# Epoch 481/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6748 - loss: 1.3173
# Epoch 482/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6754 - loss: 1.2682
# Epoch 483/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6826 - loss: 1.2725
# Epoch 484/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6740 - loss: 1.2994
# Epoch 485/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6709 - loss: 1.3141
# Epoch 486/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6814 - loss: 1.2487
# Epoch 487/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6763 - loss: 1.2930
# Epoch 488/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6694 - loss: 1.3164
# Epoch 489/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6751 - loss: 1.3041
# Epoch 490/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6689 - loss: 1.2829
# Epoch 491/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6747 - loss: 1.2801
# Epoch 492/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6638 - loss: 1.3137
# Epoch 493/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6734 - loss: 1.2677
# Epoch 494/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6911 - loss: 1.2347
# Epoch 495/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6604 - loss: 1.3361
# Epoch 496/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6738 - loss: 1.2947
# Epoch 497/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6760 - loss: 1.2776
# Epoch 498/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6657 - loss: 1.2875
# Epoch 499/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6788 - loss: 1.2915
# Epoch 500/500
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6798 - loss: 1.2522

# %%
model.save('chatbot_model.keras') #Saves the trained model to the specifies file path. the model can later be reloaded to make predictions without needing to retain.
